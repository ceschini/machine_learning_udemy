# %% [markdown]
# # Introdução ao Machine Learning

# %% [markdown]
# - Estaremos usando o livro **Introduction to Statistical Learning**, de Gareth James.
# - Consultar o livro caso precise de base matemática.
# - Ler primeiro capítulo 1 e 2 para ganhar conhecimento básico antes de ver as aulas.

# %% [markdown]
# ## O que é Machine Learning?

# %% [markdown]
# - Método de análise de dados que automatiza o processo de criação de modelos.
# - Usando algoritmos que iterativamente aprendem dos dados, Machine Learning permite que computadores encontrem padrões escondidos nos dados sem terem sido programados para isso.

# %%
from IPython.display import Image
Image("img/processo_basico_machine_learning.png")

# %% [markdown]
# #### Existem 3 tipos de algoritmos de Machine Learning

# %% [markdown]
# - Supervised Learning (Aprendizado supervisionado)
# - Unsupervised Learning (Aprendizado não supervisionado)
# - Reinforcement Learning (Aprendizado por reforço)

# %% [markdown]
# ##### Supervised Learning

# %% [markdown]
# Parâmetros rotulados que são usados para construir o modelo e tentar predizer os demais rótulos, baseados nos parâmetros apenas.

# %% [markdown]
# Ex: Características técnicas de peças de equipamentos que falharam "F" e não falharam "NF", querendo predizer o comportamento das demais peças.

# %% [markdown]
# - O algoritmo de aprendizado recebe entradas com as saídas corretas e ajusta o seu modelo de forma iterativa para que o mesmo se adapte às condições apresentadas no **conjunto de dados de treino**.
# - Então o algoritmo confere a precisão do modelo criado usando o **conjunto de dados de teste**.

# %% [markdown]
# ##### Unsupervised Learning

# %% [markdown]
# Parâmetros sem rótulos onde se quer encontrar subgrupos dentro dos dados que possuam algum tipo de semelhança.

# %% [markdown]
# - Usado quando os dados não possuem classificações prévias.
# - A resposta correta não é dita ao algoritmo, cabendo a ele encontrar padrões nos dados e agrupá-los/classificá-los baseado nas similaridades no conjunto de parâmetros.

# %% [markdown]
# - Técnicas populares incluem mapas auto-organizáveis, *k-means clustering* e *singular value decomposition*.
# - Estes algoritmos também são usados para segmentar texto em tópicos, identificação de *outliers* em conjuntos de dados e recomendação de itens à clientes.

# %% [markdown]
# ##### Reinforcement Learning

# %% [markdown]
# Algoritmos que aprendem a executar ações baseados em experiências do mesmo com algum meio.

# %% [markdown]
# - Usado principalmente em robótica, jogos e navegação.
# - Algoritmo aprende através de tentativa e erro quais pares de estado-ação obtém a maior recompensa no longo prazo.

# %% [markdown]
# - Objetivo do agente é escolher ações que maximizem a recompensa esperada dada uma determinada quantidade de tempo.
# - O agente irá, dessa forma, criar uma política de tomada de decisões, baseada no seu atual estado.

# %% [markdown]
# ### Como vai funcionar o curso

# %% [markdown]
# Para cada algoritmo ou tópico de Machine Learning:
#
# - Leitura recomendada.
# - Breve resumo da teoria.
# - Demonstração do algoritmo em Python.
# - Projeto de Machine Learning (exercícios).
# - Solução do projeto.
